# %%
import tensorflow as tf
from tensorflow.keras import layers, Model
import numpy as np
import matplotlib.pyplot as plt

# %%
def unet_model(input_shape=(128, 128, 4), num_classes=10):

    image_input = layers.Input(shape=input_shape, name="image_input")
    label_input = layers.Input(shape=(num_classes,), name="label_input")

    # 라벨 데이터를 이미지 크기로 확장
    label_embedding = layers.Dense(input_shape[0] * input_shape[1])(label_input)
    label_embedding = layers.Reshape((input_shape[0], input_shape[1], 1))(label_embedding)

    # 이미지와 라벨 결합
    inputs = layers.Concatenate()([image_input, label_embedding])

    # 인코더 (Contracting Path)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D(pool_size=(2, 2))(c4)

    # 중간 레이어 (Bottleneck)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # 디코더 (Expanding Path)
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    # 출력 레이어 (Sigmoid를 사용하여 0~1 사이의 확률값으로 출력)
    outputs = layers.Conv2D(4, (1, 1), activation='relu')(c9)

    model = Model(inputs=[image_input, label_input], outputs=[outputs])
    return model

# 모델 생성 및 컴파일
unet = unet_model(input_shape=(128, 128, 4), num_classes=10)
unet.compile(optimizer='adam', loss='mse', metrics=['accuracy'])
unet.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ label_input (InputLayer)  │ (None, 10)             │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 16384)          │        180,224 │ label_input[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_input (InputLayer)  │ (None, 128, 128, 4)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 128, 128, 1)    │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 128, 128, 5)    │              0 │ image_input[0][0],     │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 128, 128, 64)   │          2,944 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 64)   │         36,928 │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 64, 64, 64)     │              0 │ conv2d_1[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 128)    │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 64, 64, 128)    │        147,584 │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 32, 32, 128)    │              0 │ conv2d_3[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 32, 32, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 32, 32, 256)    │        590,080 │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 16, 16, 256)    │              0 │ conv2d_5[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 16, 16, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 16, 16, 512)    │      2,359,808 │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 8, 8, 512)      │              0 │ conv2d_7[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 8, 8, 1024)     │      4,719,616 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 8, 8, 1024)     │      9,438,208 │ conv2d_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      2,097,664 │ conv2d_9[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │ (Concatenate)             │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 16, 16, 512)    │      4,719,104 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 16, 16, 512)    │      2,359,808 │ conv2d_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │        524,544 │ conv2d_11[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 32, 32, 256)    │      1,179,904 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 32, 32, 256)    │        590,080 │ conv2d_12[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 128)    │        131,200 │ conv2d_13[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 64, 64, 256)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 64, 64, 128)    │        295,040 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 64, 64, 128)    │        147,584 │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 64)   │         32,832 │ conv2d_15[0][0]        │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 128, 128, 128)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 128, 128, 64)   │         73,792 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 128, 128, 64)   │         36,928 │ conv2d_16[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 128, 128, 4)    │            260 │ conv2d_17[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,213,316 (119.07 MB)
#  Trainable params: 31,213,316 (119.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from google.colab import drive
drive.mount('/content/drive')

FOLDERNAME = 'NIPA/a-yo-image'
assert FOLDERNAME is not None, "[!] Enter the foldername."

import sys
sys.path.append('/content/drive/MyDrive/{}'.format(FOLDERNAME))

# Change dariectory to current folder
# %cd /content/drive/MyDrive/$FOLDERNAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NIPA/a-yo-image

# %%
def label_to_one_hot(labels, num_classes, repeat):
  now_label_dataset = np.zeros((num_classes))
  now_label_dataset[labels]  = 1
  now_label_dataset = np.expand_dims(now_label_dataset, axis=0)
  now_label_dataset = np.repeat(now_label_dataset, repeats=repeat, axis=0)
  return now_label_dataset

# %%
dataset = np.load('./initial-experiments/mongoose/data/data_run_offset_flip.npy')
# Split into train and validation sets using indexing to optimize memory.

x_dataset = dataset[:,0,:,:,:]
y_dataset = dataset[:,1,:,:,:]
rr  = x_dataset.shape[0]
label_dataset = label_to_one_hot(1,10, rr)

for i in range(8) :
  x_dataset = np.concatenate((x_dataset, dataset[:,0,:,:,:] ), axis = 0)
  y_dataset = np.concatenate((y_dataset, dataset[:,i+2,:,:,:] ), axis = 0)
  label_dataset = np.concatenate((label_dataset, label_to_one_hot(i + 2,10, rr)), axis = 0)

print('data set shape----------------')
print(x_dataset.shape)
print(y_dataset.shape)
print(label_dataset.shape)

indexes = np.arange(x_dataset.shape[0])
np.random.shuffle(indexes)


x_train = x_dataset[indexes[: int(0.9 * x_dataset.shape[0])]]
y_train = y_dataset[indexes[: int(0.9 * x_dataset.shape[0])]]
label_train = label_dataset[indexes[: int(0.9 * x_dataset.shape[0])]]

x_test = x_dataset[indexes[int(0.9 * x_dataset.shape[0]) :]]
y_test = y_dataset[indexes[int(0.9 * x_dataset.shape[0]) :]]
label_test = label_dataset[indexes[int(0.9 * x_dataset.shape[0]) :]]

print('train_data set shape----------------')
print(x_train.shape)
print(y_train.shape)
print(label_train.shape)
print('test_data set shape----------------')
print(x_test.shape)
print(y_test.shape)
print(label_test.shape)
# Out:
# data set shape----------------
# (2295, 128, 128, 4)
# (2295, 128, 128, 4)
# (2295, 10)
# train_data set shape----------------
# (2065, 128, 128, 4)
# (2065, 128, 128, 4)
# (2065, 10)
# test_data set shape----------------
# (230, 128, 128, 4)
# (230, 128, 128, 4)
# (230, 10)

# %%
# 원본 이미지 및 재구성 이미지 시각화
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # 원본 이미지
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_train[i].reshape(128, 128, 4), cmap="gray")
    plt.axis("off")

    # 재구성 이미지
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(y_train[i].reshape(128, 128,4 ), cmap="gray")
    plt.axis("off")
plt.show()

# %%
from tensorflow.keras.callbacks import EarlyStopping
# 모델 학습from tensorflow.keras.callbacks import EarlyStopping
# 얼리 스토핑 콜백 설정
early_stopping = EarlyStopping(
    monitor='val_loss',     # 검토할 메트릭 ('val_loss'도 사용 가능)
    patience=10,         # 성능 개선 없이 기다릴 에포크 수
    restore_best_weights=True  # 최상의 가중치를 복원할지 여부
)

# 예시 데이터셋: x_train은 입력 이미지, y_train은 분할 마스크
unet.fit((x_train, label_train), y_train, epochs=2000, batch_size=16, shuffle=True,  validation_data=((x_test, label_test), y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 102s 471ms/step - accuracy: 0.0639 - loss: 1883.2147 - val_accuracy: 0.3141 - val_loss: 732.4401
# Epoch 2/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 76s 222ms/step - accuracy: 0.3305 - loss: 659.5809 - val_accuracy: 0.8459 - val_loss: 529.5679
# Epoch 3/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 225ms/step - accuracy: 0.8309 - loss: 513.1197 - val_accuracy: 0.8694 - val_loss: 460.8773
# Epoch 4/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 223ms/step - accuracy: 0.8820 - loss: 416.5886 - val_accuracy: 0.8829 - val_loss: 371.8673
# Epoch 5/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.5751 - loss: 1425.1062 - val_accuracy: 0.4934 - val_loss: 651.9523
# Epoch 6/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.4788 - loss: 629.8510 - val_accuracy: 0.2656 - val_loss: 493.0694
# Epoch 7/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.2442 - loss: 466.9165 - val_accuracy: 0.3736 - val_loss: 445.4529
# Epoch 8/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 223ms/step - accuracy: 0.2676 - loss: 446.8007 - val_accuracy: 0.4977 - val_loss: 373.9563
# Epoch 9/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.6149 - loss: 379.0153 - val_accuracy: 0.9021 - val_loss: 377.6227
# Epoch 10/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 223ms/step - accuracy: 0.8556 - loss: 363.8655 - val_accuracy: 0.8608 - val_loss: 324.7422
# Epoch 11/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 223ms/step - accuracy: 0.8711 - loss: 326.2535 - val_accuracy: 0.8732 - val_loss: 312.0208
# Epoch 12/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 219ms/step - accuracy: 0.8810 - loss: 335.1131 - val_accuracy: 0.9229 - val_loss: 316.8294
# Epoch 13/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.8904 - loss: 328.0172 - val_accuracy: 0.9163 - val_loss: 282.7224
# Epoch 14/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 223ms/step - accuracy: 0.8927 - loss: 297.1679 - val_accuracy: 0.8917 - val_loss: 275.5474
# Epoch 15/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 216ms/step - accuracy: 0.8777 - loss: 275.2226 - val_accuracy: 0.9404 - val_loss: 256.8729
# Epoch 16/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 220ms/step - accuracy: 0.9052 - loss: 262.7538 - val_accuracy: 0.9204 - val_loss: 231.7808
# Epoch 17/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 30s 227ms/step - accuracy: 0.9211 - loss: 258.1588 - val_accuracy: 0.9276 - val_loss: 225.8409
# Epoch 18/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 219ms/step - accuracy: 0.9264 - loss: 224.8996 - val_accuracy: 0.9708 - val_loss: 218.8048
# Epoch 19/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9435 - loss: 227.9418 - val_accuracy: 0.9432 - val_loss: 213.9092
# Epoch 20/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9514 - loss: 225.8346 - val_accuracy: 0.9827 - val_loss: 229.3430
# Epoch 21/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.9510 - loss: 233.1645 - val_accuracy: 0.9400 - val_loss: 237.3771
# Epoch 22/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 218ms/step - accuracy: 0.9457 - loss: 210.3510 - val_accuracy: 0.9516 - val_loss: 210.0584
# Epoch 23/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9348 - loss: 205.9819 - val_accuracy: 0.9435 - val_loss: 187.9115
# Epoch 24/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.9514 - loss: 184.2288 - val_accuracy: 0.9751 - val_loss: 239.6932
# Epoch 25/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 217ms/step - accuracy: 0.9411 - loss: 220.0285 - val_accuracy: 0.9461 - val_loss: 189.5630
# Epoch 26/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9567 - loss: 171.7516 - val_accuracy: 0.9516 - val_loss: 197.7319
# Epoch 27/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 224ms/step - accuracy: 0.9569 - loss: 169.9167 - val_accuracy: 0.9471 - val_loss: 173.5358
# Epoch 28/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 218ms/step - accuracy: 0.9540 - loss: 174.1565 - val_accuracy: 0.9515 - val_loss: 181.4778
# Epoch 29/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9547 - loss: 159.5388 - val_accuracy: 0.9521 - val_loss: 191.3774
# Epoch 30/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.9510 - loss: 177.4769 - val_accuracy: 0.9539 - val_loss: 161.7200
# Epoch 31/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.9516 - loss: 159.3279 - val_accuracy: 0.9496 - val_loss: 170.2440
# Epoch 32/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9524 - loss: 174.6331 - val_accuracy: 0.9447 - val_loss: 204.3208
# Epoch 33/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.9432 - loss: 180.3926 - val_accuracy: 0.9522 - val_loss: 153.6508
# Epoch 34/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 217ms/step - accuracy: 0.9573 - loss: 142.2708 - val_accuracy: 0.9517 - val_loss: 150.5579
# Epoch 35/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 222ms/step - accuracy: 0.9561 - loss: 149.7862 - val_accuracy: 0.9879 - val_loss: 151.8594
# Epoch 36/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.9563 - loss: 147.7685 - val_accuracy: 0.9672 - val_loss: 141.9712
# Epoch 37/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 218ms/step - accuracy: 0.9575 - loss: 131.0758 - val_accuracy: 0.9537 - val_loss: 139.2529
# Epoch 38/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9503 - loss: 146.3865 - val_accuracy: 0.9454 - val_loss: 146.8183
# Epoch 39/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.9450 - loss: 145.7639 - val_accuracy: 0.9537 - val_loss: 134.4648
# Epoch 40/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9518 - loss: 117.3435 - val_accuracy: 0.9515 - val_loss: 143.7964
# Epoch 41/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9566 - loss: 132.6263 - val_accuracy: 0.9531 - val_loss: 135.9907
# Epoch 42/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9633 - loss: 108.5421 - val_accuracy: 0.9529 - val_loss: 150.5570
# Epoch 43/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9403 - loss: 138.4170 - val_accuracy: 0.9897 - val_loss: 151.4632
# Epoch 44/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 218ms/step - accuracy: 0.9578 - loss: 139.3642 - val_accuracy: 0.9529 - val_loss: 134.3182
# Epoch 45/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9540 - loss: 132.7212 - val_accuracy: 0.9532 - val_loss: 129.1540
# Epoch 46/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9547 - loss: 119.7489 - val_accuracy: 0.9556 - val_loss: 120.2122
# Epoch 47/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 217ms/step - accuracy: 0.9575 - loss: 100.6810 - val_accuracy: 0.9906 - val_loss: 121.3289
# Epoch 48/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9528 - loss: 105.4509 - val_accuracy: 0.9909 - val_loss: 123.0964
# Epoch 49/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9613 - loss: 106.6405 - val_accuracy: 0.9552 - val_loss: 119.1290
# Epoch 50/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 219ms/step - accuracy: 0.9599 - loss: 100.2317 - val_accuracy: 0.9551 - val_loss: 122.4243
# Epoch 51/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.9528 - loss: 99.9314 - val_accuracy: 0.9537 - val_loss: 151.4453
# Epoch 52/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9615 - loss: 138.1393 - val_accuracy: 0.9557 - val_loss: 127.2151
# Epoch 53/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.9552 - loss: 98.6778 - val_accuracy: 0.9578 - val_loss: 117.1299
# Epoch 54/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9618 - loss: 96.6140 - val_accuracy: 0.9907 - val_loss: 132.1947
# Epoch 55/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9574 - loss: 103.4608 - val_accuracy: 0.9927 - val_loss: 125.0937
# Epoch 56/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 222ms/step - accuracy: 0.9582 - loss: 125.9570 - val_accuracy: 0.9558 - val_loss: 118.4819
# Epoch 57/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 219ms/step - accuracy: 0.9577 - loss: 103.5444 - val_accuracy: 0.9543 - val_loss: 114.8784
# Epoch 58/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 217ms/step - accuracy: 0.9547 - loss: 112.8942 - val_accuracy: 0.9564 - val_loss: 115.7749
# Epoch 59/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 221ms/step - accuracy: 0.9551 - loss: 93.3777 - val_accuracy: 0.9571 - val_loss: 108.6885
# Epoch 60/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 216ms/step - accuracy: 0.9541 - loss: 87.4168 - val_accuracy: 0.9939 - val_loss: 108.5641
# Epoch 61/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.9695 - loss: 83.9346 - val_accuracy: 0.9556 - val_loss: 124.2321
# Epoch 62/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 222ms/step - accuracy: 0.9600 - loss: 117.0352 - val_accuracy: 0.9570 - val_loss: 105.5122
# Epoch 63/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 218ms/step - accuracy: 0.9597 - loss: 81.8947 - val_accuracy: 0.9928 - val_loss: 106.5929
# Epoch 64/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 216ms/step - accuracy: 0.9676 - loss: 83.7945 - val_accuracy: 0.9588 - val_loss: 110.5583
# Epoch 65/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 223ms/step - accuracy: 0.9666 - loss: 86.8573 - val_accuracy: 0.9553 - val_loss: 101.2912
# Epoch 66/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 220ms/step - accuracy: 0.9650 - loss: 72.5431 - val_accuracy: 0.9551 - val_loss: 110.1078
# Epoch 67/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9621 - loss: 97.6148 - val_accuracy: 0.9884 - val_loss: 118.6302
# Epoch 68/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 217ms/step - accuracy: 0.9640 - loss: 94.2937 - val_accuracy: 0.9445 - val_loss: 374.4230
# Epoch 69/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 212ms/step - accuracy: 0.9443 - loss: 266.2075 - val_accuracy: 0.9525 - val_loss: 157.2092
# Epoch 70/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 211ms/step - accuracy: 0.9562 - loss: 129.9323 - val_accuracy: 0.9842 - val_loss: 147.4106
# Epoch 71/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 221ms/step - accuracy: 0.9609 - loss: 113.0304 - val_accuracy: 0.9579 - val_loss: 113.4502
# Epoch 72/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 216ms/step - accuracy: 0.9582 - loss: 91.8531 - val_accuracy: 0.9549 - val_loss: 108.2167
# Epoch 73/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 221ms/step - accuracy: 0.9552 - loss: 91.2858 - val_accuracy: 0.9557 - val_loss: 101.4760
# Epoch 74/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 221ms/step - accuracy: 0.9510 - loss: 80.7839 - val_accuracy: 0.9900 - val_loss: 94.3404
# Epoch 75/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9654 - loss: 70.9072 - val_accuracy: 0.9912 - val_loss: 94.9652
# Epoch 76/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 217ms/step - accuracy: 0.9655 - loss: 69.2243 - val_accuracy: 0.9553 - val_loss: 132.3869
# Epoch 77/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 42s 222ms/step - accuracy: 0.9533 - loss: 142.6137 - val_accuracy: 0.9537 - val_loss: 141.8735
# Epoch 78/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 28s 217ms/step - accuracy: 0.9523 - loss: 147.0162 - val_accuracy: 0.9874 - val_loss: 182.4733
# Epoch 79/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 218ms/step - accuracy: 0.9567 - loss: 159.5981 - val_accuracy: 0.9533 - val_loss: 187.8721
# Epoch 80/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 220ms/step - accuracy: 0.9572 - loss: 139.2444 - val_accuracy: 0.9574 - val_loss: 122.2207
# Epoch 81/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 215ms/step - accuracy: 0.9566 - loss: 93.7848 - val_accuracy: 0.9908 - val_loss: 111.2447
# Epoch 82/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 29s 221ms/step - accuracy: 0.9643 - loss: 80.7286 - val_accuracy: 0.9930 - val_loss: 104.2157
# Epoch 83/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 40s 215ms/step - accuracy: 0.9598 - loss: 88.1154 - val_accuracy: 0.9558 - val_loss: 99.8025
# Epoch 84/2000
# 130/130 ━━━━━━━━━━━━━━━━━━━━ 41s 219ms/step - accuracy: 0.9558 - loss: 77.2272 - val_accuracy: 0.9563 - val_loss: 98.8126

# %%
x_test.shape
# Out:
# (230, 128, 128, 4)

# %%
x_test_head = x_test[:5, :, :, :]
new_x_test = x_test_head[:1].repeat(10, axis=0)
for i in range(4) :
  new_x_test = np.concatenate((new_x_test, x_test_head[i + 1 : i + 2].repeat(10, axis=0)), axis=0)

# %%
test_label = np.zeros((50, 10))
for i in range(50) :
  test_label[i, i % 10] = 1

# %%
test_label.shape
# Out:
# (50, 10)

# %%
decoded_imgs = unet.predict((new_x_test, test_label))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 35s 16s/step

# %%
# 원본 이미지 및 재구성 이미지 시각화
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # 원본 이미지
    if i == 0 :
      ax = plt.subplot(2, n, i + 1)
      plt.imshow(x_test[i].reshape(128, 128, 4), cmap="gray")
      plt.axis("off")
    else :
      # 재구성 이미지
      ax = plt.subplot(2, n, i + 1)
      plt.imshow(decoded_imgs[i].reshape(128, 128,4 ), cmap="gray")
      plt.axis("off")
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
